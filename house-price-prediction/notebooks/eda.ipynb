# %% [markdown]
# # 🏠 House Price Prediction - Exploratory Data Analysis (EDA)
#
# This notebook performs basic exploratory data analysis on the housing dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('train.csv')
df.head()

# %%
# Dataset Info
df.info()

# %%
# Statistical Summary
df.describe()

# %%
# Distribution of SalePrice
plt.figure()
plt.hist(df['SalePrice'], bins=30)
plt.title('SalePrice Distribution')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation with SalePrice
correlation = df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)
correlation
